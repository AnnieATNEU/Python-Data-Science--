# %%
# Adding Images
from IPython.display import Image
Image(filename='scatterplot.png') #make sure the image is in the same folder with this jupyter file

# %%
# Adding Images 
#another way
from PIL import Image
img = Image.open('scatterplot.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x352 at 0x19B785ECA60>
